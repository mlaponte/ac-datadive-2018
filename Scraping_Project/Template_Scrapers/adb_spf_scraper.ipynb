# %%
import requests
from scraperutils import *
from datamodel import Fields
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'}
page = requests.get("https://www.adb.org/site/accountability-mechanism/problem-solving-function/complaint-registry-year", headers=headers)
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# Function to get Project-Sector 
def extract_sector_info(sector_data):
    sectors = []
    sectors_and_subsectors = sector_data.split("\n")
    for i in range(len(sectors_and_subsectors)):
        sectors_and_subsectors[i] = sectors_and_subsectors[i].replace("\n", "")
        if '/' in sectors_and_subsectors[i]:
            sectors.append(sectors_and_subsectors[i].replace("/", "").strip())
    return ";".join(sectors)

# Function to retrieve additional data from Project-Links
def update_additional_project_details(table, project_details):
    table_info = {}
    table_rows = table.find_all('tr')
    project_details_fields = ['Project Number', 'Project Status','Project Type / Modality of Assistance','Sector / Subsector', 'Description']
    for i in range(0,len(table_rows)):
        row = table_rows[i]
        data = row.find_all('td')
        if len(data) == 2 and data[0].text.strip() in project_details_fields:
            table_info[data[0].text.strip()] = data[1].text
    
    # Adding the Project-Number
    project_details[Fields.PROJECT_NUMBER.name] = table_info['Project Number']
    
    # Adding the Project-Status
    project_details[Fields.COMPLAINT_STATUS.name] = table_info.get('Project Status')
    
    # Adding the Project-Type
    if  table_info.get('Project Type / Modality of Assistance') is not None:
        project_details[Fields.PROJECT_TYPE.name] = table_info.get('Project Type / Modality of Assistance').split('\n')[:-1]
        
    # Adding the Project-Sector  
    project_details[Fields.SECTOR.name] = extract_sector_info(table_info.get('Sector / Subsector'))

# Function to retrive the Project-timeline
def update_project_lifecycle_details(lifecycle_info, project_details):
    lifecycle_stages = lifecycle_info.find_all('li')
    for stage in lifecycle_stages:
        if 'received' in stage.text:
            project_details[Fields.FILING_DATE.name] = stage.text.split(",")[1]
            project_details[Fields.REGISTRATION_START_DATE.name] = project_details[Fields.FILING_DATE.name] 
        if 'registered' in stage.text:
            project_details[Fields.REGISTRATION_END_DATE.name] = stage.text.split(",")[1]
            project_details[Fields.ELIGIBILITY_START_DATE.name] = project_details[Fields.REGISTRATION_END_DATE.name]
        if 'eligibility' in stage.text:
            project_details[Fields.ELIGIBILITY_END_DATE.name] = stage.text.split(",")[1]
        if 'Assessment' in stage.text:
            project_details[Fields.DISPUTE_RESOLUTION_START_DATE.name] = stage.text.split(",")[1]
        
        if project_details.get(Fields.COMPLAINT_STATUS.name) == 'Closed':
            project_details[Fields.DATE_CLOSED.name] = 'Completed'
            
            if project_details.get(Fields.DISPUTE_RESOLUTION_START_DATE.name) is not None:
                project_details[Fields.DISPUTE_RESOLUTION_END_DATE.name] = 'Completed'

# %%
tables = soup.find_all('table', {'class':['table-striped table-secondary']})
project_output = []

for table in tables:
    rows = table.find_all('tr')
    for i in range (1,len(rows)):
        project_details = dict()
        data = rows[i].find_all('td')
        
        # Adding the Project-Year        
        project_details[Fields.YEAR.name] = data[0].text.split('/')[1]
    
        # Adding the Project-Country
        project_details[Fields.COUNTRY.name] = data[1].text.split(':')[0]

        # Adding the Project-Name 
        project_details[Fields.PROJECT_NAME.name] = data[1].text.split(':')[1]
        
        # Adding the Project-ID 
        project_details[Fields.PROJECT_ID.name] = data[1].text
        
        # Adding the Project-Issues 
        project_details[Fields.ISSUES.name] = data[2].ul.text.split('\n')[:-1]
        
        # Adding the Project-ProjectLink 
        if (data[1].find('a') is not None):
            project_details[Fields.HYPERLINK.name] = data[1].find('a').get("href")
            i_page = None
            # Getting each project details
            if ("https://www.adb.org/" in project_details[Fields.HYPERLINK.name]):
                i_page = requests.get(project_details[Fields.HYPERLINK.name]+"#project-pds", headers=headers)
            else: 
                i_page = requests.get("https://www.adb.org/"+project_details[Fields.HYPERLINK.name]+"#project-pds", headers=headers)
                
            soup1 = BeautifulSoup(i_page.content, 'html.parser')
            table = soup1.find('table',{'class':'pds'})
            update_additional_project_details(table, project_details)
            
        # Adding the Project-Complaint-Documents 
        if (data[3].find('a') is not None):
            project_details[Fields.DOCUMENTS.name] = data[3].find('a').get("href")
        
        update_project_lifecycle_details(data[3], project_details)
        project_output.append(project_details)
        
        print(get_complete_project_row(project_details))

write_csv("adb_spf_scraper", project_output)
#print (project_output)
# Out:
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2018'), ('COUNTRY', 'Pakistan'), ('PROJECT_NAME', ' Flood Emergency Reconstruction and Resilience Project'), ('PROJECT_ID', 'Pakistan: Flood Emergency Reconstruction and Resilience Project'), ('PROJECT_NUMBER', '49038-001'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['LoanTechnical Assistance']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Agriculture, natural resources and rural development;Transport'), ('ISSUES', ['Substandard reconstruction of road']), ('FILERS', None), ('FILING_DATE', ' 11 June 2018'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/49038-001/main'), ('REGISTRATION_START_DATE', ' 11 June 2018'), ('REGISTRATION_END_DATE', ' 14 June 2018'), ('ELIGIBILITY_START_DATE', ' 14 June 2018'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2018'), ('COUNTRY', 'Pakistan'), ('PROJECT_NAME', ' Peshawar Sustainable Bus Rapid Transit Corridor Project'), ('PROJECT_ID', 'Pakistan: Peshawar Sustainable Bus Rapid Transit Corridor Project'), ('PROJECT_NUMBER', '48289-001'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Technical Assistance']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport;Water and other urban infrastructure and services'), ('ISSUES', ['Business loss/profit', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 10 May 2018'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/48289-001/main'), ('REGISTRATION_START_DATE', ' 10 May 2018'), ('REGISTRATION_END_DATE', ' 15 May 2018'), ('ELIGIBILITY_START_DATE', ' 15 May 2018'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/pak-48289-001-complaint-form.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2018'), ('COUNTRY', 'Pakistan'), ('PROJECT_NAME', ' National Highway Network Development in Balochistan Project'), ('PROJECT_ID', 'Pakistan: National Highway Network Development in Balochistan Project'), ('PROJECT_NUMBER', '47281-001'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['GrantLoan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Land ownership', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 6 April 2018'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/47281-001/main'), ('REGISTRATION_START_DATE', ' 6 April 2018'), ('REGISTRATION_END_DATE', ' 11 April 2018'), ('ELIGIBILITY_START_DATE', ' 11 April 2018'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2018'), ('COUNTRY', 'Mongolia'), ('PROJECT_NAME', ' Ulaanbaatar Urban Services and Ger Areas Development Investment Program - Tranche 1'), ('PROJECT_ID', 'Mongolia: Ulaanbaatar Urban Services and Ger Areas Development Investment Program - Tranche 1'), ('PROJECT_NUMBER', '45007-004'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['GrantLoan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Energy;Transport;Water and other urban infrastructure and services'), ('ISSUES', ['Information and consultation', 'Land and property valuation']), ('FILERS', None), ('FILING_DATE', ' 28 March 2018'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', 'https://www.adb.org/projects/45007-004/main'), ('REGISTRATION_START_DATE', ' 28 March 2018'), ('REGISTRATION_END_DATE', ' 2 April 2018'), ('ELIGIBILITY_START_DATE', ' 2 April 2018'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/mon-45007-004-complaint-form.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2018'), ('COUNTRY', 'Georgia'), ('PROJECT_NAME', ' Adjaristsqali Hydropower Project'), ('PROJECT_ID', 'Georgia: Adjaristsqali Hydropower Project'), ('PROJECT_NUMBER', '47919-014'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Energy'), ('ISSUES', ['Impacts of the project on the natural and social environment of the village', 'Village safety']), ('FILERS', None), ('FILING_DATE', ' 8 March 2018'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', 'https://www.adb.org/projects/47919-014/main'), ('REGISTRATION_START_DATE', ' 8 March 2018'), ('REGISTRATION_END_DATE', ' 8 March 2018'), ('ELIGIBILITY_START_DATE', ' 8 March 2018'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2018'), ('COUNTRY', 'Bangladesh'), ('PROJECT_NAME', ' SASEC Second Bangladesh-India Electrical Grid Interconnection Project'), ('PROJECT_ID', 'Bangladesh: SASEC Second Bangladesh-India Electrical Grid Interconnection Project'), ('PROJECT_NUMBER', '44192-016'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Energy'), ('ISSUES', ['High voltage transmission line crossing property', 'Health issues']), ('FILERS', None), ('FILING_DATE', ' 22 February 2018'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', 'https://www.adb.org/projects/44192-016/main'), ('REGISTRATION_START_DATE', ' 22 February 2018'), ('REGISTRATION_END_DATE', ' 22 February 2018'), ('ELIGIBILITY_START_DATE', ' 22 February 2018'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/ban-44192-016-complaint-form.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2018'), ('COUNTRY', 'Armenia'), ('PROJECT_NAME', ' Sustainable Urban Development Investment Program - Tranche 1'), ('PROJECT_ID', 'Armenia: Sustainable Urban Development Investment Program - Tranche 1'), ('PROJECT_NUMBER', '42417-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Impact of road construction to property and people’s safety', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 12 February 2018'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', 'https://www.adb.org/projects/42417-023/main'), ('REGISTRATION_START_DATE', ' 12 February 2018'), ('REGISTRATION_END_DATE', ' 15 February 2018'), ('ELIGIBILITY_START_DATE', ' 15 February 2018'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2018'), ('COUNTRY', 'Kazakhstan'), ('PROJECT_NAME', ' Akmola Electricity Distribution Network Modernization and Expansion Project'), ('PROJECT_ID', 'Kazakhstan: Akmola Electricity Distribution Network Modernization and Expansion Project'), ('PROJECT_NUMBER', '46933-014'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Energy'), ('ISSUES', ['High cost of new equipment and connection fee to the grid network']), ('FILERS', None), ('FILING_DATE', ' 15 January 2018'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', 'https://www.adb.org/projects/46933-014/main'), ('REGISTRATION_START_DATE', ' 15 January 2018'), ('REGISTRATION_END_DATE', ' 15 January 2018'), ('ELIGIBILITY_START_DATE', ' 15 January 2018'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/kaz-akmola-electricity-distribution-project-complaint-form.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', 'Bangladesh'), ('PROJECT_NAME', ' Third Urban Governance and Infrastructure Improvement (Sector) Project – Additional Financing'), ('PROJECT_ID', 'Bangladesh: Third Urban Governance and Infrastructure Improvement (Sector) Project – Additional Financing'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Road construction', 'Tree Cutting']), ('FILERS', None), ('FILING_DATE', ' 25 October 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 25 October 2017'), ('REGISTRATION_END_DATE', ' 27 October 2017'), ('ELIGIBILITY_START_DATE', ' 27 October 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/ban-ugiip3-af-complaint-letter.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', 'Sri Lanka'), ('PROJECT_NAME', ' Clean Energy and Network Efficiency Improvement Project'), ('PROJECT_ID', 'Sri Lanka: Clean Energy and Network Efficiency Improvement Project'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Alignment of transmission line going through houses and land', 'Health issues']), ('FILERS', None), ('FILING_DATE', ' 5 October 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 5 October 2017'), ('REGISTRATION_END_DATE', ' 6 October 2017'), ('ELIGIBILITY_START_DATE', ' 6 October 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nArmenia'), ('PROJECT_NAME', ' Sustainable Urban Development Investment Program – Tranche 1\n'), ('PROJECT_ID', '\nArmenia: Sustainable Urban Development Investment Program – Tranche 1\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Impact of road construction to property and people’s safety', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 5 September 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 5 September 2017'), ('REGISTRATION_END_DATE', ' 6 September 2017'), ('ELIGIBILITY_START_DATE', ' 6 September 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/arm-sudip-t1-complaint-letter.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nGeorgia'), ('PROJECT_NAME', ' Batumi Bypass Road Project\n'), ('PROJECT_ID', '\nGeorgia: Batumi Bypass Road Project\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Property and land valuation', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 24 August 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 24 August 2017'), ('REGISTRATION_END_DATE', ' 28 August 2017'), ('ELIGIBILITY_START_DATE', ' 28 August 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/geo-batumi-bypass-road-complaint-form.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nNepal'), ('PROJECT_NAME', ' Decentralized Rural Infrastructure and Livelihood Project – Additional Financing\n'), ('PROJECT_ID', '\nNepal: Decentralized Rural Infrastructure and Livelihood Project – Additional Financing\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Land donation', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 22 August 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 22 August 2017'), ('REGISTRATION_END_DATE', ' 23 August 2017'), ('ELIGIBILITY_START_DATE', ' 23 August 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/nep-drilp-af-complaint-form.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nSri Lanka'), ('PROJECT_NAME', ' Clean Energy and Network Efficiency Improvement Project\n'), ('PROJECT_ID', '\nSri Lanka: Clean Energy and Network Efficiency Improvement Project\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Alignment of transmission line differs from the approved path', 'No environmental Study for the new alignment']), ('FILERS', None), ('FILING_DATE', ' 16 August 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 16 August 2017'), ('REGISTRATION_END_DATE', ' 17 August 2017'), ('ELIGIBILITY_START_DATE', ' 17 August 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/sri-clean-energy-network-efficiency-complaint-form.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nGeorgia'), ('PROJECT_NAME', ' MFF-Sustainable Urban Transport Investment Program - Tranche 3\n'), ('PROJECT_ID', '\nGeorgia: MFF-Sustainable Urban Transport Investment Program - Tranche 3\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Loss of business', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 14 August 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 14 August 2017'), ('REGISTRATION_END_DATE', ' 15 August 2017'), ('ELIGIBILITY_START_DATE', ' 15 August 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nGeorgia'), ('PROJECT_NAME', ' MFF-Sustainable Urban Transport Investment Program - Tranche 3\n'), ('PROJECT_ID', '\nGeorgia: MFF-Sustainable Urban Transport Investment Program - Tranche 3\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Material harm due to road construction', 'Health issues']), ('FILERS', None), ('FILING_DATE', ' 10 July 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 10 July 2017'), ('REGISTRATION_END_DATE', ' 10 July 2017'), ('ELIGIBILITY_START_DATE', ' 10 July 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/geo-mff-sustainable-urban-transport-t3.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nSri Lanka'), ('PROJECT_NAME', ' Greater Colombo Wastewater Management Project\n'), ('PROJECT_ID', '\nSri Lanka: Greater Colombo Wastewater Management Project\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Vibration and noise', 'Damage to property', 'Health issue']), ('FILERS', None), ('FILING_DATE', ' 19 April 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 19 April 2017'), ('REGISTRATION_END_DATE', ' 19 April 2017'), ('ELIGIBILITY_START_DATE', ' 19 April 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/sri-greater-colombo-wastewater-mngt.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nGeorgia'), ('PROJECT_NAME', ' MFF-Sustainable Urban Transport Investment Program - Tranche 3 (Section 2, Part B of the Tbilisi-Rustavi Urban Road Link)\n'), ('PROJECT_ID', '\nGeorgia: MFF-Sustainable Urban Transport Investment Program - Tranche 3 (Section 2, Part B of the Tbilisi-Rustavi Urban Road Link)\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Evaluation of property', 'Land acquisition and Compensation']), ('FILERS', None), ('FILING_DATE', ' 10 April 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 10 April 2017'), ('REGISTRATION_END_DATE', ' 11 April 2017'), ('ELIGIBILITY_START_DATE', ' 11 April 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/geo-sustainable-urban-transport-t3.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nSri Lanka'), ('PROJECT_NAME', ' Greater Colombo Water and Wastewater Management Improvement Investment Program – Tranche 3\n'), ('PROJECT_ID', '\nSri Lanka: Greater Colombo Water and Wastewater Management Improvement Investment Program – Tranche 3\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Compensation', 'Resettlement', 'Consultation']), ('FILERS', None), ('FILING_DATE', ' 24 March 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 24 March 2017'), ('REGISTRATION_END_DATE', ' 24 March 2017'), ('ELIGIBILITY_START_DATE', ' 24 March 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/sri-greater-colombo-water-wastewater-mngt-t3.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2017'), ('COUNTRY', '\nSri Lanka'), ('PROJECT_NAME', ' Green Power Development and Energy Efficiency Improvement Investment Program\nSri Lanka'), ('PROJECT_ID', '\nSri Lanka: Green Power Development and Energy Efficiency Improvement Investment Program\nSri Lanka: Green Power Development and Energy Efficiency Improvement Investment Program - Tranche 1\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Environmental and sociological impacts', 'Impact on people, livelihood and business']), ('FILERS', None), ('FILING_DATE', ' 31 Jan 2017'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 31 Jan 2017'), ('REGISTRATION_END_DATE', ' 1 Feb 2017'), ('ELIGIBILITY_START_DATE', ' 1 Feb 2017'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/sri-green-power-dev-complaint-form-31jan2017.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2016'), ('COUNTRY', '\nIndia'), ('PROJECT_NAME', ' Uttarakhand State-Road Investment Program – Tranche 3\n'), ('PROJECT_ID', '\nIndia: Uttarakhand State-Road Investment Program – Tranche 3\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['', 'Dust Pollution, health impacts, and road accidents due to construction delays', '', '', 'Lack of project monitoring', '']), ('FILERS', None), ('FILING_DATE', ' 25 Nov 2016'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 25 Nov 2016'), ('REGISTRATION_END_DATE', ' 28 Nov 2016'), ('ELIGIBILITY_START_DATE', ' 28 Nov 2016'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/india-uttarakhand-state-road-investment-program–tranche-3.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2016'), ('COUNTRY', '\nGeorgia'), ('PROJECT_NAME', ' MFF Sustainable Urban Transport Investment Program - Tranche 2 (3rd section of Tbilisi-Rustavi Road)\n'), ('PROJECT_ID', '\nGeorgia: MFF Sustainable Urban Transport Investment Program - Tranche 2 (3rd section of Tbilisi-Rustavi Road)\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['', 'Reimbursement of business investments', '', '', 'Compensation for loss of business', '']), ('FILERS', None), ('FILING_DATE', ' 17 Nov 2016'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 17 Nov 2016'), ('REGISTRATION_END_DATE', ' 17 Nov 2016'), ('ELIGIBILITY_START_DATE', ' 17 Nov 2016'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2016'), ('COUNTRY', '\nGeorgia'), ('PROJECT_NAME', ' MFF Sustainable Urban Transport Investment Program - Tranche 2 (Section 3)\n'), ('PROJECT_ID', '\nGeorgia: MFF Sustainable Urban Transport Investment Program - Tranche 2 (Section 3)\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['', 'Access to main road resulting to loss of business', '', '', 'Compensation', '']), ('FILERS', None), ('FILING_DATE', ' 9 Nov 2016'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 9 Nov 2016'), ('REGISTRATION_END_DATE', ' 9 Nov 2016'), ('ELIGIBILITY_START_DATE', ' 9 Nov 2016'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/geo-42414-033-complaint-en.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2016'), ('COUNTRY', '\nGeorgia'), ('PROJECT_NAME', ' MFF Sustainable Urban Transport Investment - Program Tranche 3\n'), ('PROJECT_ID', '\nGeorgia: MFF Sustainable Urban Transport Investment - Program Tranche 3\n'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['', 'Loss of business, compensation, and consultation', '']), ('FILERS', None), ('FILING_DATE', ' 27 May 2016\nEnglish\nGeorgian\n'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 27 May 2016\nEnglish\nGeorgian\n'), ('REGISTRATION_END_DATE', ' 30 May 2016'), ('ELIGIBILITY_START_DATE', ' 30 May 2016'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/geo-urban-transport-complaint-en.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2016'), ('COUNTRY', 'Georgia'), ('PROJECT_NAME', ' MFF Sustainable Urban Transport Investment Program – Tranche 3'), ('PROJECT_ID', 'Georgia: MFF Sustainable Urban Transport Investment Program – Tranche 3'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Compensation and resettlement']), ('FILERS', None), ('FILING_DATE', ' 28 Apr 2016\nEnglish\nGeorgian\n'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 28 Apr 2016\nEnglish\nGeorgian\n'), ('REGISTRATION_END_DATE', ' 28 Apr 2016'), ('ELIGIBILITY_START_DATE', ' 28 Apr 2016'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', ' 28 Sep 2016\nEnglish\nGeorgian\n'), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/geo-42414-043-complaint-english.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2016'), ('COUNTRY', 'Pakistan'), ('PROJECT_NAME', ' MFF Power Distribution Enhancement Investment Program – Tranche 2'), ('PROJECT_ID', 'Pakistan: MFF Power Distribution Enhancement Investment Program – Tranche 2'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Horizontal clearance for 132 Kv electric wire crossing properties and other structures']), ('FILERS', None), ('FILING_DATE', ' 18 Mar 2016'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 18 Mar 2016'), ('REGISTRATION_END_DATE', ' 21 Mar 2016'), ('ELIGIBILITY_START_DATE', ' 21 Mar 2016'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/pak-power-program-complaint.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2015'), ('COUNTRY', 'Nepal'), ('PROJECT_NAME', ' Melamchi Water Supply Project'), ('PROJECT_ID', 'Nepal: Melamchi Water Supply Project'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Repair of road used for pipe extension']), ('FILERS', None), ('FILING_DATE', ' 15 Jul 2015'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 15 Jul 2015'), ('REGISTRATION_END_DATE', ' 16 Jul 2015'), ('ELIGIBILITY_START_DATE', ' 16 Jul 2015'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/nep-melamchi-water-complaint-letter-15jul15.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2014'), ('COUNTRY', 'Nepal'), ('PROJECT_NAME', ' Decentralized Rural Infrastructure and Livelihood Project'), ('PROJECT_ID', 'Nepal: Decentralized Rural Infrastructure and Livelihood Project'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Lack of information and consultation', 'Land acquisition', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 2 Dec 2014'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 2 Dec 2014'), ('REGISTRATION_END_DATE', ' 3 Dec 2014'), ('ELIGIBILITY_START_DATE', ' 3 Dec 2014'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/final-report-nep-complaint-loan2796-grant0267.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2014'), ('COUNTRY', 'Samoa'), ('PROJECT_NAME', ' TAs 8481 and 7387 (SAM)'), ('PROJECT_ID', 'Samoa: TAs 8481 and 7387 (SAM): Promoting Economic Use of Customary Land and Grant No. 0392 (SAM): Samoa Agribusiness Support Project'), ('PROJECT_NUMBER', '46436-002'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Grant']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Agriculture, natural resources and rural development'), ('ISSUES', ['Lack of Consultation', 'Use of customary land', 'Inadequate environment and social due diligence', 'Disclosure of documents']), ('FILERS', None), ('FILING_DATE', ' 9 Sep 2014'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/46436-002/main'), ('REGISTRATION_START_DATE', ' 9 Sep 2014'), ('REGISTRATION_END_DATE', ' 9 Sep 2014'), ('ELIGIBILITY_START_DATE', ' 9 Sep 2014'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', ' 24 Mar 2015'), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/complaints-sam-matais-sep14.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2014'), ('COUNTRY', 'Nepal'), ('PROJECT_NAME', ' Secondary Towns Integrated Urban Environmental Improvement Project'), ('PROJECT_ID', 'Nepal: Secondary Towns Integrated Urban Environmental Improvement Project'), ('PROJECT_NUMBER', '36188-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport;Water and other urban infrastructure and services'), ('ISSUES', ['Lack of consultation', 'Non-provision of drinking water and irrigation facilities']), ('FILERS', None), ('FILING_DATE', ' 18 Feb 2014'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/36188-023/main'), ('REGISTRATION_START_DATE', ' 18 Feb 2014'), ('REGISTRATION_END_DATE', ' 19 Feb 2014'), ('ELIGIBILITY_START_DATE', ' 19 Feb 2014'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/nep-complain-letter-feb-2014.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2013'), ('COUNTRY', 'Pakistan'), ('PROJECT_NAME', ' Emergency Reconstruction Project'), ('PROJECT_ID', 'Pakistan: Emergency Reconstruction Project'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Quality of reconstruction works']), ('FILERS', None), ('FILING_DATE', ' 9 Dec 2013'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 9 Dec 2013'), ('REGISTRATION_END_DATE', ' 9 Dec 2013'), ('ELIGIBILITY_START_DATE', ' 9 Dec 2013'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/complaint-letter-pak-emergency-reconstruction.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2013'), ('COUNTRY', 'Armenia'), ('PROJECT_NAME', ' Zvartnots Airport Expansion Project (Phase 2)'), ('PROJECT_ID', 'Armenia: Zvartnots Airport Expansion Project (Phase 2)'), ('PROJECT_NUMBER', '43922-014'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Resettlement', 'Consultation', 'Information']), ('FILERS', None), ('FILING_DATE', ' 1 Aug 2013'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/43922-014/main'), ('REGISTRATION_START_DATE', ' 1 Aug 2013'), ('REGISTRATION_END_DATE', ' 6 Aug 2013'), ('ELIGIBILITY_START_DATE', ' 6 Aug 2013'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/arm-2nd-complaint-1aug2013.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2013'), ('COUNTRY', 'Kyrgyz Republic'), ('PROJECT_NAME', ' Loan 2755 (SF)'), ('PROJECT_ID', 'Kyrgyz Republic: Loan 2755 (SF): CAREC Corridor 1 (Bishkek-Torugart Road) Project 3'), ('PROJECT_NUMBER', '42399-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Environment', 'Information Sharing']), ('FILERS', None), ('FILING_DATE', ' 11 Jul 2013\nEnglish\nRussian\n'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/42399-023/main'), ('REGISTRATION_START_DATE', ' 11 Jul 2013\nEnglish\nRussian\n'), ('REGISTRATION_END_DATE', ' 12 Jul 2013'), ('ELIGIBILITY_START_DATE', ' 12 Jul 2013'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/kgz-complaint-letter-carec-corridor-1-eng.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2013'), ('COUNTRY', 'Armenia'), ('PROJECT_NAME', ' Zvartnots Airport Expansion Project (Phase 2)'), ('PROJECT_ID', 'Armenia: Zvartnots Airport Expansion Project (Phase 2)'), ('PROJECT_NUMBER', '43922-014'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Resettlement', 'Consultation', 'Information']), ('FILERS', None), ('FILING_DATE', ' 4 Jul 2013\nEnglish\nArmenian\n'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/43922-014/main'), ('REGISTRATION_START_DATE', ' 4 Jul 2013\nEnglish\nArmenian\n'), ('REGISTRATION_END_DATE', ' 5 Jul 2013'), ('ELIGIBILITY_START_DATE', ' 5 Jul 2013'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/arm-zvartnots-complaint-letter-blocked-en.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2013'), ('COUNTRY', 'Cambodia'), ('PROJECT_NAME', ' Rehabilitation of the Railway in Cambodia Project'), ('PROJECT_ID', 'Cambodia: Rehabilitation of the Railway in Cambodia Project'), ('PROJECT_NUMBER', '37269-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['GrantLoan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Resettlement', 'Compensation', 'Consultation']), ('FILERS', None), ('FILING_DATE', ' 26 Mar 2013\nEnglish\nKhmer\n'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/37269-023/main'), ('REGISTRATION_START_DATE', ' 26 Mar 2013\nEnglish\nKhmer\n'), ('REGISTRATION_END_DATE', ' 27 Mar 2013'), ('ELIGIBILITY_START_DATE', ' 27 Mar 2013'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/cam-complaint-letter-english-26march2013.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2013'), ('COUNTRY', 'Cambodia'), ('PROJECT_NAME', ' Rehabilitation of the Railway in Cambodia Project'), ('PROJECT_ID', 'Cambodia: Rehabilitation of the Railway in Cambodia Project'), ('PROJECT_NUMBER', '37269-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['GrantLoan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Resettlement', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 25 Feb 2013\nEnglish\nKhmer\n'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/37269-023/main'), ('REGISTRATION_START_DATE', ' 25 Feb 2013\nEnglish\nKhmer\n'), ('REGISTRATION_END_DATE', None), ('ELIGIBILITY_START_DATE', None), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/cam-3rd-complaint-final-english-letter.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2012'), ('COUNTRY', 'India'), ('PROJECT_NAME', ' Kerala Sustainable Urban Development Project'), ('PROJECT_ID', 'India: Kerala Sustainable Urban Development Project'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Lack of Information', 'Environmental Impact', 'Village Infrastructure Affected', 'Lack of Consultation']), ('FILERS', None), ('FILING_DATE', ' 4 Sep 2012'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 4 Sep 2012'), ('REGISTRATION_END_DATE', None), ('ELIGIBILITY_START_DATE', None), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2012'), ('COUNTRY', 'Cambodia'), ('PROJECT_NAME', ' Rehabilitation of the Railway in Cambodia Project'), ('PROJECT_ID', 'Cambodia: Rehabilitation of the Railway in Cambodia Project'), ('PROJECT_NUMBER', '37269-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['GrantLoan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Resettlement']), ('FILERS', None), ('FILING_DATE', ' 13 Apr 2012\nEnglish\nKhmer\n'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/37269-023/main'), ('REGISTRATION_START_DATE', ' 13 Apr 2012\nEnglish\nKhmer\n'), ('REGISTRATION_END_DATE', ' 19 Apr 2012'), ('ELIGIBILITY_START_DATE', ' 19 Apr 2012'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/complaint-letter-en-cam-railway-2012.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2011'), ('COUNTRY', 'Kazakhstan'), ('PROJECT_NAME', ' CAREC Transport Corridor I Investment Program'), ('PROJECT_ID', 'Kazakhstan: CAREC Transport Corridor I Investment Program'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Environment']), ('FILERS', None), ('FILING_DATE', ' 20 Dec 2011'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 20 Dec 2011'), ('REGISTRATION_END_DATE', ' 21 Dec 2011'), ('ELIGIBILITY_START_DATE', ' 21 Dec 2011'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2011'), ('COUNTRY', 'Cambodia'), ('PROJECT_NAME', ' Rehabilitation of the Railway in Cambodia Project'), ('PROJECT_ID', 'Cambodia: Rehabilitation of the Railway in Cambodia Project'), ('PROJECT_NUMBER', '37269-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['GrantLoan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Resettlement', 'Information', 'Consultation']), ('FILERS', None), ('FILING_DATE', ' 21 Nov 2011'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/37269-023/main'), ('REGISTRATION_START_DATE', ' 21 Nov 2011'), ('REGISTRATION_END_DATE', ' 23 Nov 2011'), ('ELIGIBILITY_START_DATE', ' 23 Nov 2011'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', ' 17 Feb 2012'), ('DISPUTE_RESOLUTION_END_DATE', 'Completed'), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/cam-complaint-letter-8feb2012.pdf')])
# ...
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2009'), ('COUNTRY', "People's Republic of China"), ('PROJECT_NAME', ' Fuzhou Environmental Improvement Project'), ('PROJECT_ID', "People's Republic of China: Fuzhou Environmental Improvement Project"), ('PROJECT_NUMBER', '35340-013'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Water and other urban infrastructure and services'), ('ISSUES', ['Resettlement']), ('FILERS', None), ('FILING_DATE', ' 15 Jan 2009\nEnglish\nChinese\n'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/35340-013/main'), ('REGISTRATION_START_DATE', ' 15 Jan 2009\nEnglish\nChinese\n'), ('REGISTRATION_END_DATE', ' 19 Jan 2009'), ('ELIGIBILITY_START_DATE', ' 19 Jan 2009'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', ' 23 Mar 2009\nEnglish\nChinese\n'), ('DISPUTE_RESOLUTION_END_DATE', 'Completed'), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/fuzhou-project.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2007'), ('COUNTRY', 'Cambodia'), ('PROJECT_NAME', ' Phnom Penh to Ho Chi Minh City Highway Project'), ('PROJECT_ID', 'Cambodia: Phnom Penh to Ho Chi Minh City Highway Project'), ('PROJECT_NUMBER', '30316-013'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Compensation', 'Land Titling', 'Livelihood']), ('FILERS', None), ('FILING_DATE', ' 30 Jul 2007'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Approved'), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/30316-013/main'), ('REGISTRATION_START_DATE', ' 30 Jul 2007'), ('REGISTRATION_END_DATE', ' 6 Aug 2007'), ('ELIGIBILITY_START_DATE', ' 6 Aug 2007'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', ' 24 Oct 2007\nEnglish\nKhmer\n'), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/cam-rar-final-25feb2011.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2007'), ('COUNTRY', 'Nepal'), ('PROJECT_NAME', ' Urban and Environmental Improvement Project'), ('PROJECT_ID', 'Nepal: Urban and Environmental Improvement Project'), ('PROJECT_NUMBER', '32239-013'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Finance;Health;Transport;Water and other urban infrastructure and services'), ('ISSUES', ['Information', 'Consultation']), ('FILERS', None), ('FILING_DATE', ' 11 Jan 2007'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/32239-013/main'), ('REGISTRATION_START_DATE', ' 11 Jan 2007'), ('REGISTRATION_END_DATE', ' 08 Feb 2007'), ('ELIGIBILITY_START_DATE', ' 08 Feb 2007'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/complaint-letter.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2006'), ('COUNTRY', 'Viet Nam'), ('PROJECT_NAME', ' GMS Mekong Tourism Development Project'), ('PROJECT_ID', 'Viet Nam: GMS Mekong Tourism Development Project'), ('PROJECT_NUMBER', '35345-013'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Industry and trade'), ('ISSUES', ['Compensation', 'Information']), ('FILERS', None), ('FILING_DATE', ' 1 letter\n19 Dec 2006'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/35345-013/main'), ('REGISTRATION_START_DATE', ' 1 letter\n19 Dec 2006'), ('REGISTRATION_END_DATE', ' 9 Jan 2007'), ('ELIGIBILITY_START_DATE', ' 9 Jan 2007'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2006'), ('COUNTRY', 'India'), ('PROJECT_NAME', ' Assam Power Sector Development Project'), ('PROJECT_ID', 'India: Assam Power Sector Development Project'), ('PROJECT_NUMBER', '36318-013'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Energy'), ('ISSUES', ['Procurement']), ('FILERS', None), ('FILING_DATE', ' 31 Oct 2006'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/36318-013/main'), ('REGISTRATION_START_DATE', ' 31 Oct 2006'), ('REGISTRATION_END_DATE', ' registered and referred to relevant units in ADB'), ('ELIGIBILITY_START_DATE', ' registered and referred to relevant units in ADB'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2006'), ('COUNTRY', 'Pakistan'), ('PROJECT_NAME', ' National Highway Development Sector Investment Program'), ('PROJECT_ID', 'Pakistan: National Highway Development Sector Investment Program'), ('PROJECT_NUMBER', '37559-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Land acquisition and compensation', 'Resettlement', 'Information']), ('FILERS', None), ('FILING_DATE', ' 9 Sep 2006'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/37559-023/main'), ('REGISTRATION_START_DATE', ' 9 Sep 2006'), ('REGISTRATION_END_DATE', ' 10 Jan 2007'), ('ELIGIBILITY_START_DATE', ' 10 Jan 2007'), ('ELIGIBILITY_END_DATE', ' establishing contact and fielding a pre-eligibility inquiry'), ('DISPUTE_RESOLUTION_START_DATE', ' 12 Mar 2007English\nUrdu\n'), ('DISPUTE_RESOLUTION_END_DATE', 'Completed'), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/complaint-letter-2231-sf-pak.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2006'), ('COUNTRY', 'Nepal'), ('PROJECT_NAME', ' Rural Electrification, Distribution and Transmission Project-Thankot-Chapagaun-Bhaktapur 132 kV Transmission Line'), ('PROJECT_ID', 'Nepal: Rural Electrification, Distribution and Transmission Project-Thankot-Chapagaun-Bhaktapur 132 kV Transmission Line'), ('PROJECT_NUMBER', '29471-013'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Energy'), ('ISSUES', ['Consultation', 'Compensation']), ('FILERS', None), ('FILING_DATE', ' 25 Apr 2006'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/29471-013/main'), ('REGISTRATION_START_DATE', ' 25 Apr 2006'), ('REGISTRATION_END_DATE', ' 28 Apr 2006'), ('ELIGIBILITY_START_DATE', ' 28 Apr 2006'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2006'), ('COUNTRY', 'Bangladesh'), ('PROJECT_NAME', ' Khulna-Jessore Drainage Rehabilitation Project'), ('PROJECT_ID', 'Bangladesh: Khulna-Jessore Drainage Rehabilitation Project'), ('PROJECT_NUMBER', '21087'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', ''), ('ISSUES', ['Agricultural production', 'Community Participation']), ('FILERS', None), ('FILING_DATE', ' 4 Jan 2006'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/ln1289/main'), ('REGISTRATION_START_DATE', ' 4 Jan 2006'), ('REGISTRATION_END_DATE', ' 4 Jan 2006'), ('ELIGIBILITY_START_DATE', ' 4 Jan 2006'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2006'), ('COUNTRY', 'Pakistan'), ('PROJECT_NAME', ' Chasma Right Bank Irrigation Project-Stage III'), ('PROJECT_ID', 'Pakistan: Chasma Right Bank Irrigation Project-Stage III'), ('PROJECT_NUMBER', None), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', None), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', None), ('ISSUES', ['Distributary link', 'Flooding']), ('FILERS', None), ('FILING_DATE', ' 14 Dec 2005'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', None), ('DATE_CLOSED', None), ('HYPERLINK', None), ('REGISTRATION_START_DATE', ' 14 Dec 2005'), ('REGISTRATION_END_DATE', ' 15 Dec 2005'), ('ELIGIBILITY_START_DATE', ' 15 Dec 2005'), ('ELIGIBILITY_END_DATE', ' translations'), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/pak-chasma-complaint.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2005'), ('COUNTRY', 'Indonesia'), ('PROJECT_NAME', ' Community Empowerment for Rural Development Project'), ('PROJECT_ID', 'Indonesia: Community Empowerment for Rural Development Project'), ('PROJECT_NUMBER', '32367-013'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Agriculture, natural resources and rural development;Finance;Public sector management'), ('ISSUES', ['Village Infrastructure', 'Community Participation', 'Information Sharing']), ('FILERS', None), ('FILING_DATE', ' 21 Feb 2005'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/32367-013/main'), ('REGISTRATION_START_DATE', ' 21 Feb 2005'), ('REGISTRATION_END_DATE', ' 9 Mar 2005'), ('ELIGIBILITY_START_DATE', ' 9 Mar 2005'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', ' 5 May 2005\nEnglish\nBahasa Indonesia\n'), ('DISPUTE_RESOLUTION_END_DATE', 'Completed'), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/cerdp-final-rar.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2004'), ('COUNTRY', 'Philippines'), ('PROJECT_NAME', ' Sixth Road Project'), ('PROJECT_ID', 'Philippines: Sixth Road Project'), ('PROJECT_NUMBER', '23233'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', ''), ('ISSUES', ['Consultation', 'Information', 'Business Income']), ('FILERS', None), ('FILING_DATE', ' 27 Sep 2004'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/ln1473/main'), ('REGISTRATION_START_DATE', ' 27 Sep 2004'), ('REGISTRATION_END_DATE', ' 28 Sep 2004'), ('ELIGIBILITY_START_DATE', ' 28 Sep 2004'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', None), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', None)])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2004'), ('COUNTRY', 'Sri Lanka'), ('PROJECT_NAME', ' Southern Transport Development Project (STDP)'), ('PROJECT_ID', 'Sri Lanka: Southern Transport Development Project (STDP)'), ('PROJECT_NUMBER', '26522-013'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Transport'), ('ISSUES', ['Environmental Impact Assessment (EIA)', 'Social Impact Assessment (SIA)', 'Compensation and Resettlement']), ('FILERS', None), ('FILING_DATE', ' 9 Jun 2004'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Closed'), ('DATE_CLOSED', 'Completed'), ('HYPERLINK', '/projects/26522-013/main'), ('REGISTRATION_START_DATE', ' 9 Jun 2004'), ('REGISTRATION_END_DATE', ' 16 Jun 2004'), ('ELIGIBILITY_START_DATE', ' 16 Jun 2004'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', ' 17 Sep 2004'), ('DISPUTE_RESOLUTION_END_DATE', 'Completed'), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/conflict-management-report.pdf')])
# OrderedDict([('IAM', None), ('IAM_ID', None), ('YEAR', '2004'), ('COUNTRY', 'Nepal'), ('PROJECT_NAME', ' Melamchi Water Supply Project (MWSP)'), ('PROJECT_ID', 'Nepal: Melamchi Water Supply Project (MWSP)'), ('PROJECT_NUMBER', '31624-023'), ('RELATED_PROJECT_NUMBER', None), ('PROJECT_TYPE', ['Loan']), ('PROJECT_LOAN_AMOUNT', None), ('SECTOR', 'Water and other urban infrastructure and services'), ('ISSUES', ['Access to information', 'Environmental Impact Assessment (EIA)', 'Land acquisition, compensation and resettlement', 'Indigenous peoples', 'Social Uplift Program', 'Agriculture', 'Forestry']), ('FILERS', None), ('FILING_DATE', ' 3 May 2004'), ('ENVIRONMENTAL_CATEGORY', None), ('COMPLAINT_STATUS', 'Active'), ('DATE_CLOSED', None), ('HYPERLINK', '/projects/31624-023/main'), ('REGISTRATION_START_DATE', ' 3 May 2004'), ('REGISTRATION_END_DATE', ' 3 May 2004'), ('ELIGIBILITY_START_DATE', ' 3 May 2004'), ('ELIGIBILITY_END_DATE', None), ('DISPUTE_RESOLUTION_START_DATE', ' 25 Jun 2004'), ('DISPUTE_RESOLUTION_END_DATE', None), ('COMPLIANCE_REVIEW_START_DATE', None), ('COMPLIANCE_REVIEW_END_DATE', None), ('MONITORING_START_DATE', None), ('MONITORING_END_DATE', None), ('IS_COMPLIANCE_REPORT_ISSUED', None), ('DOCUMENTS', '/sites/default/files/page/42458/review-report.pdf')])

# %%
# Out:
# datetime.datetime(2018, 6, 23, 17, 40, 24, 796783)
